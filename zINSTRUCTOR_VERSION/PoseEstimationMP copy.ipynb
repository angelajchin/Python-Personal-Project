# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
import math
import time
import cv2
import pandas as pd
from pathlib import Path
from ultralytics import YOLO
from pydantic import BaseModel

# We want to be able to resize images by scale factor. It is a common practice to preprocess images in computer vision models
scale_factor = 0.5
def resize_image(image, scale_factor):
    # Calculate the new dimensions
    new_width = int(image.shape[1] * scale_factor)
    new_height = int(image.shape[0] * scale_factor)

    # Resize the image
    resized_image = cv2.resize(image, (new_width, new_height))

    return resized_image

# Defines constants corresponding to different parts of the body
class GetKeypoint(BaseModel):
    NOSE: int = 0
    LEFT_EYE: int = 1
    RIGHT_EYE: int = 2
    LEFT_EAR: int = 3
    RIGHT_EAR: int = 4
    LEFT_SHOULDER: int = 5
    RIGHT_SHOULDER: int = 6
    LEFT_ELBOW: int = 7
    RIGHT_ELBOW: int = 8
    LEFT_WRIST: int = 9
    RIGHT_WRIST: int = 10
    LEFT_HIP: int = 11
    RIGHT_HIP: int = 12
    LEFT_KNEE: int = 13
    RIGHT_KNEE: int = 14
    LEFT_ANKLE: int = 15
    RIGHT_ANKLE: int = 16

get_keypoint = GetKeypoint()

# Specify the path of the video you want to process
video_path = '../Videos/AnteriorParkinsons.mp4'  # Replace with your video path

# Open video capture
cap = cv2.VideoCapture(video_path)
model = YOLO('yolov8n-pose.pt')  # Ensure you have the correct YOLO model

# Initialize variables for angular and linear velocities (for future calculations)
prev_angle = None
prev_angular_velocity = None
prev_linear_velocity = None
linear_acceleration = None
angular_velocity = None
prev_time = 0
data_list = []

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    try:
        # Resize the image & get the current frame time
        frame = resize_image(frame, scale_factor)
        current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000

        # Get the results from the YOLO model at that current frame with a 0.7 conf
        results = model(frame, conf=0.7)

        # Retrieve keypoints from the result and take their xyn coordinates
        result_keypoint = results[0].keypoints.xyn.cpu().numpy()

        index = 0
        if len(result_keypoint) > 1 and result_keypoint[0][get_keypoint.RIGHT_ANKLE][0] > result_keypoint[1][get_keypoint.RIGHT_ANKLE][0]:
            index = 1
        print('index', index)

        # Extract the keypoints: Nose, Eyes, Ears, Shoulders, Elbows, Wrists, Hips, Knees, and Ankles
        nose = result_keypoint[index][get_keypoint.NOSE]
        left_eye = result_keypoint[index][get_keypoint.LEFT_EYE]
        right_eye = result_keypoint[index][get_keypoint.RIGHT_EYE]
        left_ear = result_keypoint[index][get_keypoint.LEFT_EAR]
        right_ear = result_keypoint[index][get_keypoint.RIGHT_EAR]
        left_shoulder = result_keypoint[index][get_keypoint.LEFT_SHOULDER]
        right_shoulder = result_keypoint[index][get_keypoint.RIGHT_SHOULDER]
        left_elbow = result_keypoint[index][get_keypoint.LEFT_ELBOW]
        right_elbow = result_keypoint[index][get_keypoint.RIGHT_ELBOW]
        left_wrist = result_keypoint[index][get_keypoint.LEFT_WRIST]
        right_wrist = result_keypoint[index][get_keypoint.RIGHT_WRIST]
        left_hip = result_keypoint[index][get_keypoint.LEFT_HIP]
        right_hip = result_keypoint[index][get_keypoint.RIGHT_HIP]
        left_knee = result_keypoint[index][get_keypoint.LEFT_KNEE]
        right_knee = result_keypoint[index][get_keypoint.RIGHT_KNEE]
        left_ankle = result_keypoint[index][get_keypoint.LEFT_ANKLE]
        right_ankle = result_keypoint[index][get_keypoint.RIGHT_ANKLE]

        # Here we calculate angular velocity and other metrics using the right leg (for example purposes)
        vector1 = (right_knee[0] - right_ankle[0], right_knee[1] - right_ankle[1])
        vector2 = (right_hip[0] - right_ankle[0], right_hip[1] - right_ankle[1])

        # Calculate angle between the vectors
        dot_product = vector1[0] * vector2[0] + vector1[1] * vector2[1]
        magnitude1 = math.sqrt(vector1[0] ** 2 + vector1[1] ** 2)
        magnitude2 = math.sqrt(vector2[0] ** 2 + vector2[1] ** 2)
        angle_rad = math.acos(dot_product / (magnitude1 * magnitude2))
        angle_deg = math.degrees(angle_rad)

        # Get the time difference between frames
        time_diff = current_time - prev_time

        # Calculate angular velocity
        if prev_angle is not None:
            angular_velocity = (angle_deg - prev_angle) / time_diff
            print(f'Angular Velocity: {angular_velocity} deg/s')

        # Calculate linear acceleration if previous angular velocity exists
        if prev_angular_velocity is not None:
            linear_acceleration = (angular_velocity - prev_angular_velocity)

        # Update variables
        prev_angle = angle_deg
        prev_angular_velocity = angular_velocity
        prev_linear_acceleration = linear_acceleration
        prev_time = current_time

        # Append data to the list
        data_list.append({
            'time': current_time,
            'linear_acceleration': linear_acceleration,
            'angular_velocity': angular_velocity
        })

    except Exception as e:
        print(e)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Save the DataFrame to a CSV file
df = pd.DataFrame(data_list)
df.to_csv(f'./{Path(video_path).stem}.csv')

# Release video capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 96.5ms
# Speed: 5.0ms preprocess, 96.5ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
# index 0
#
# 0: 384x640 1 person, 49.1ms
# Speed: 0.9ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 15.13885394544012 deg/s
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.132207644746177 deg/s
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.3ms preprocess, 47.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.974342052529229 deg/s
#
# 0: 384x640 1 person, 46.4ms
# Speed: 0.8ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.639521579051484 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 0.8ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.511695051931223 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 0.8ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.742938112610821 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.528380361550948 deg/s
#
# 0: 384x640 1 person, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.0218708081877421 deg/s
#
# 0: 384x640 1 person, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.1966091553362876 deg/s
#
# 0: 384x640 1 person, 43.7ms
# Speed: 0.9ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.0915765637883037 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -19.6472634083136 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.4ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 14.919568376491473 deg/s
#
# 0: 384x640 1 person, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -13.078828365936024 deg/s
#
# 0: 384x640 1 person, 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.320376428745045 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.066420863714985 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.8576361718220475 deg/s
#
# 0: 384x640 1 person, 41.6ms
# Speed: 0.9ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.8073597827491072 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.401890021978975 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.451495264829785 deg/s
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.4109053666990565 deg/s
#
# 0: 384x640 1 person, 41.9ms
# Speed: 0.9ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.635922252613267 deg/s
#
# 0: 384x640 1 person, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.246638182676073 deg/s
#
# 0: 384x640 1 person, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 27.08028877968639 deg/s
#
# 0: 384x640 1 person, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.084499023348371 deg/s
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 5.8396608812657504 deg/s
#
# 0: 384x640 1 person, 47.5ms
# Speed: 0.9ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -28.72070829629504 deg/s
#
# 0: 384x640 1 person, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.5726534754063226 deg/s
#
# 0: 384x640 1 person, 51.6ms
# Speed: 1.1ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.9628173015921788 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 5.695387920242665 deg/s
#
# 0: 384x640 1 person, 44.8ms
# Speed: 0.8ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.136513356837177 deg/s
#
# 0: 384x640 1 person, 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.159834258945203 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.15576346921537207 deg/s
#
# 0: 384x640 1 person, 47.1ms
# Speed: 0.9ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.505289960139936 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.26483827959220596 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.9382000367094303 deg/s
#
# 0: 384x640 1 person, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.1814176207276463 deg/s
#
# 0: 384x640 1 person, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.3096679371110238 deg/s
#
# 0: 384x640 1 person, 40.7ms
# Speed: 1.1ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.11813843494006986 deg/s
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.3243307232617847 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.653037281751608 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.832792321437047 deg/s
#
# 0: 384x640 1 person, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.051781566386464 deg/s
#
# 0: 384x640 1 person, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 5.953814186788769 deg/s
#
# 0: 384x640 1 person, 46.7ms
# Speed: 0.9ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.7834021422601536 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.902511327975882 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.4ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -6.741719070021182 deg/s
#
# 0: 384x640 1 person, 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.665414728777835 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.414061000937907 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 0.9ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.748922345968521 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.012226955305724 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.9586813001163867 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.8776774794627116 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.9309017393370769 deg/s
#
# 0: 384x640 1 person, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.2232691575723065 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 0.8ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.5746192255902973 deg/s
#
# 0: 384x640 1 person, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.6117945474003696 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.1529234445746223 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.7738978122874793 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.38574150013692 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.6454170021498542 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.952278104647941 deg/s
#
# 0: 384x640 1 person, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -6.4031220807566225 deg/s
#
# 0: 384x640 1 person, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.4818449514587977 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 0.9ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 20.61054852416171 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 0.9ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 12.357170314740348 deg/s
#
# 0: 384x640 1 person, 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.34547141284913 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.7799757937671117 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.9719799174804398 deg/s
#
# 0: 384x640 1 person, 40.8ms
# Speed: 0.9ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.909132977195625 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -12.983068272284969 deg/s
#
# 0: 384x640 1 person, 47.2ms
# Speed: 0.9ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.705724539958316 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.304650598813268 deg/s
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.821119218346213 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.6434748105130375 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.6666047422315393 deg/s
#
# 0: 384x640 1 person, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.2465145371680197 deg/s
#
# 0: 384x640 1 person, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.5777491934847065 deg/s
#
# 0: 384x640 1 person, 45.5ms
# Speed: 0.9ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.66309968889365 deg/s
#
# 0: 384x640 1 person, 46.9ms
# Speed: 0.9ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.5881514686709899 deg/s
#
# 0: 384x640 1 person, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.3109510322093445 deg/s
#
# 0: 384x640 1 person, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.214694274078372 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.3273445107979565 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.7258096363030644 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 0.9ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 6.147137589423 deg/s
#
# 0: 384x640 1 person, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.2386597805406643 deg/s
#
# 0: 384x640 1 person, 43.6ms
# Speed: 0.8ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.696662029612305 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.342891011378422 deg/s
#
# 0: 384x640 1 person, 42.9ms
# Speed: 0.9ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.336521088510472 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.956230111809659 deg/s
#
# 0: 384x640 1 person, 50.6ms
# Speed: 0.9ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 31.727263184160424 deg/s
#
# 0: 384x640 1 person, 47.8ms
# Speed: 1.1ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -34.42549505879291 deg/s
#
# 0: 384x640 1 person, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.267279002633169 deg/s
#
# 0: 384x640 1 person, 82.4ms
# Speed: 0.9ms preprocess, 82.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.6598277648840005 deg/s
#
# 0: 384x640 1 person, 48.5ms
# Speed: 1.3ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.6113763052455743 deg/s
#
# 0: 384x640 1 person, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 6.443814210844744 deg/s
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.7ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.688996230436115 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.448003140193032 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.240142993385644 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 0.8ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.683975502828801 deg/s
#
# 0: 384x640 1 person, 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.33682261478082215 deg/s
#
# 0: 384x640 1 person, 44.9ms
# Speed: 0.8ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.195751507030982 deg/s
#
# 0: 384x640 1 person, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.249452389560576 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.090073076060491 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.2942954559768298 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.3554420018203053 deg/s
#
# 0: 384x640 1 person, 42.9ms
# Speed: 0.8ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.118938850141983 deg/s
#
# 0: 384x640 1 person, 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0006801301052233998 deg/s
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.5ms
# Speed: 0.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.08628512600326066 deg/s
#
# 0: 384x640 1 person, 46.0ms
# Speed: 0.9ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.08010682766690155 deg/s
#
# 0: 384x640 1 person, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.0600033233650922 deg/s
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0036617692274648304 deg/s
#
# 0: 384x640 1 person, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.2ms
# Speed: 1.3ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0029362411077722855 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.00820222216165894 deg/s
#
# 0: 384x640 1 person, 43.8ms
# Speed: 0.9ms preprocess, 43.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 46.7ms
# Speed: 0.8ms preprocess, 46.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.6ms
# Speed: 0.9ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 48.5ms
# Speed: 0.8ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 59.6ms
# Speed: 43.5ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.0030943138174006008 deg/s
#
# 0: 384x640 1 person, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -10.27199027897604 deg/s
#
# 0: 384x640 1 person, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.02560479891514048 deg/s
#
# 0: 384x640 1 person, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0013053875098416859 deg/s
#
# 0: 384x640 1 person, 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 38.8ms
# Speed: 0.9ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.023288235770912158 deg/s
#
# 0: 384x640 1 person, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0007994471891594318 deg/s
#
# 0: 384x640 1 person, 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.0007994471891594318 deg/s
#
# 0: 384x640 1 person, 37.8ms
# Speed: 0.9ms preprocess, 37.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0007994471891594318 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.2ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 37.6ms
# Speed: 0.9ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 41.3ms
# Speed: 0.8ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.0007994471891594318 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 38.8ms
# Speed: 1.3ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.1ms
# Speed: 3.8ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 0.9ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 46.5ms
# Speed: 0.8ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.2ms
# Speed: 0.9ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 47.1ms
# Speed: 0.9ms preprocess, 47.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.009527249531923913 deg/s
#
# 0: 384x640 1 person, 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.009527249531923913 deg/s
#
# 0: 384x640 1 person, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 50.3ms
# Speed: 1.4ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 45.8ms
# Speed: 0.8ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.7ms
# Speed: 1.3ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.1ms
# Speed: 4.6ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.3ms
# Speed: 0.9ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.15531312741466224 deg/s
#
# 0: 384x640 1 person, 42.9ms
# Speed: 0.9ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 52.2ms
# Speed: 0.9ms preprocess, 52.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.0 deg/s
#
# 0: 384x640 1 person, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.750841115259009 deg/s
#
# 0: 384x640 1 person, 71.9ms
# Speed: 0.8ms preprocess, 71.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.91140563103 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.0200340099349607 deg/s
#
# 0: 384x640 1 person, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 6.718510751673069 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.41222069958326 deg/s
#
# 0: 384x640 1 person, 41.1ms
# Speed: 0.8ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -17.156506273466164 deg/s
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.780934116110966 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -12.627607799173585 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 12.644566639462932 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 21.389515332733108 deg/s
#
# 0: 384x640 1 person, 44.3ms
# Speed: 0.8ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.191457371944372 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -8.175123812566964 deg/s
#
# 0: 384x640 1 person, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.343318969605183 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.133452602854062 deg/s
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.4ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.0148333543258443 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.5846408057754235 deg/s
#
# 0: 384x640 1 person, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.3304241319650502 deg/s
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.9589833927175289 deg/s
#
# 0: 384x640 1 person, 42.1ms
# Speed: 0.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.7813776464283284 deg/s
#
# 0: 384x640 1 person, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.293834520294628 deg/s
#
# 0: 384x640 1 person, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.861749288648711 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.222434811774363 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 10.02018133533645 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.414738820048184 deg/s
#
# 0: 384x640 1 person, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 23.68591130363867 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -17.269526875695565 deg/s
#
# 0: 384x640 1 person, 43.7ms
# Speed: 0.9ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.039029595058813 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.208571143181093 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.9442792164877405 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 0.9ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.7010839522431654 deg/s
#
# 0: 384x640 1 person, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 20.417315577665953 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 0.9ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -16.053657783869113 deg/s
#
# 0: 384x640 1 person, 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.222011765143394 deg/s
#
# 0: 384x640 1 person, 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.7970052847027658 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.88435117129838 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.5710192970145354 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.3475064178162315 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.9405826841458826 deg/s
#
# 0: 384x640 1 person, 43.1ms
# Speed: 0.8ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.0452439733961647 deg/s
#
# 0: 384x640 1 person, 44.3ms
# Speed: 0.9ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 18.453404497201465 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 0.9ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.8461597974917527 deg/s
#
# 0: 384x640 1 person, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.1447456555309983 deg/s
#
# 0: 384x640 1 person, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 11.116548190831754 deg/s
#
# 0: 384x640 1 person, 50.0ms
# Speed: 1.0ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.4523433300955366 deg/s
#
# 0: 384x640 1 person, 44.1ms
# Speed: 1.5ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.9630211550583265 deg/s
#
# 0: 384x640 1 person, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.7453199660237768 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -11.989718869811192 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.488369519565039 deg/s
#
# 0: 384x640 1 person, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.70006541706409 deg/s
#
# 0: 384x640 1 person, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.701881558234849 deg/s
#
# 0: 384x640 1 person, 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.941051416715596 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.880561513182046 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -7.554494522799757 deg/s
#
# 0: 384x640 1 person, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.5908442136754077 deg/s
#
# 0: 384x640 1 person, 42.9ms
# Speed: 1.0ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.674103579475745 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 0.7ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.582380858147129 deg/s
#
# 0: 384x640 1 person, 43.9ms
# Speed: 0.8ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -24.533473144719522 deg/s
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 15.667832962121638 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 12.235608630586905 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.6234642309848182 deg/s
#
# 0: 384x640 1 person, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 10.563086251744172 deg/s
#
# 0: 384x640 1 person, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.634670728716629 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 0.8ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.337222007918294 deg/s
#
# 0: 384x640 1 person, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 12.644350046419568 deg/s
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.991895233130896 deg/s
#
# 0: 384x640 1 person, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -8.60337092423953 deg/s
#
# 0: 384x640 1 person, 46.6ms
# Speed: 0.9ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -9.527436058375217 deg/s
#
# 0: 384x640 1 person, 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.3732763014376335 deg/s
#
# 0: 384x640 1 person, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.08690700483725607 deg/s
#
# 0: 384x640 1 person, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.0121175757706953 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.79903992556827 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.1274654039537957 deg/s
#
# 0: 384x640 1 person, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.188292468595337 deg/s
#
# 0: 384x640 1 person, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -23.3918814822393 deg/s
#
# 0: 384x640 1 person, 60.5ms
# Speed: 1.1ms preprocess, 60.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.8163824783336089 deg/s
#
# 0: 384x640 1 person, 46.4ms
# Speed: 1.8ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.435896097308484 deg/s
#
# 0: 384x640 1 person, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.392531966928384 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 0.8ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -10.616122392171448 deg/s
#
# 0: 384x640 1 person, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.958429777140424 deg/s
#
# 0: 384x640 1 person, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.43727901021099036 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 18.14391952040535 deg/s
#
# 0: 384x640 1 person, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -12.664762309606923 deg/s
#
# 0: 384x640 1 person, 83.8ms
# Speed: 1.0ms preprocess, 83.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -9.715186364970974 deg/s
#
# 0: 384x640 1 person, 56.4ms
# Speed: 7.9ms preprocess, 56.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -8.381752984562322 deg/s
#
# 0: 384x640 1 person, 56.9ms
# Speed: 0.9ms preprocess, 56.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.1587350406834993 deg/s
#
# 0: 384x640 1 person, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -14.360925373989959 deg/s
#
# 0: 384x640 1 person, 53.6ms
# Speed: 1.3ms preprocess, 53.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 10.272852179887483 deg/s
#
# 0: 384x640 1 person, 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.0555173034451846 deg/s
#
# 0: 384x640 1 person, 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.44434211198657836 deg/s
#
# 0: 384x640 1 person, 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.4702655242625328 deg/s
#
# 0: 384x640 1 person, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.364695633778974 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 0.9ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.393551629978363 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.591665655031324 deg/s
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.2ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.582715776750794 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.6285811361248217 deg/s
#
# 0: 384x640 1 person, 45.0ms
# Speed: 1.3ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# ...
#
# 0: 384x640 1 person, 36.6ms
# Speed: 0.9ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.268066776310369 deg/s
#
# 0: 384x640 1 person, 39.2ms
# Speed: 0.8ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -9.150319370311161 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -6.143480498152216 deg/s
#
# 0: 384x640 1 person, 40.5ms
# Speed: 2.5ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.5294082015820896 deg/s
#
# 0: 384x640 1 person, 39.1ms
# Speed: 0.9ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -9.135473521938339 deg/s
#
# 0: 384x640 1 person, 37.6ms
# Speed: 1.0ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.151228409627161 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.7737972716162815 deg/s
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.4271341342073076 deg/s
#
# 0: 384x640 1 person, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 14.004423913274502 deg/s
#
# 0: 384x640 1 person, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.6266908714816337 deg/s
#
# 0: 384x640 1 person, 42.7ms
# Speed: 0.8ms preprocess, 42.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.5092441372033036 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 0.9ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -14.777486331348753 deg/s
#
# 0: 384x640 1 person, 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 19.123412877507285 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.920493741874916 deg/s
#
# 0: 384x640 1 person, 47.1ms
# Speed: 22.7ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.5610029114200485 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 10.312898981217753 deg/s
#
# 0: 384x640 1 person, 42.4ms
# Speed: 1.9ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 5.755457145771167 deg/s
#
# 0: 384x640 1 person, 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.82482398079184 deg/s
#
# 0: 384x640 1 person, 37.6ms
# Speed: 0.9ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 5.9612437313485325 deg/s
#
# 0: 384x640 1 person, 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.472056391918102 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 14.230160538224547 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 20.974515849071246 deg/s
#
# 0: 384x640 1 person, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -8.176189474893498 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 0.9ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.4832846273670365 deg/s
#
# 0: 384x640 1 person, 39.4ms
# Speed: 1.3ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.688716806203449 deg/s
#
# 0: 384x640 1 person, 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 9.775138348911094 deg/s
#
# 0: 384x640 1 person, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.792079503397437 deg/s
#
# 0: 384x640 1 person, 37.0ms
# Speed: 0.8ms preprocess, 37.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -13.137104167950552 deg/s
#
# 0: 384x640 1 person, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -17.532209867980928 deg/s
#
# 0: 384x640 1 person, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -14.823872335623532 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.1ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.4495354699540948 deg/s
#
# 0: 384x640 1 person, 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -11.868532345389772 deg/s
#
# 0: 384x640 1 person, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.030549144333143378 deg/s
#
# 0: 384x640 1 person, 42.2ms
# Speed: 0.8ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -8.669977985058003 deg/s
#
# 0: 384x640 1 person, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.9035288993477308 deg/s
#
# 0: 384x640 1 person, 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.352043196849172 deg/s
#
# 0: 384x640 1 person, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 8.247321514497118 deg/s
#
# 0: 384x640 1 person, 39.1ms
# Speed: 1.2ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.995836822208513 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 1.2ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.8467359031540385 deg/s
#
# 0: 384x640 1 person, 39.1ms
# Speed: 0.8ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -4.447414486009038 deg/s
#
# 0: 384x640 1 person, 37.4ms
# Speed: 0.8ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.0080704633547433 deg/s
#
# 0: 384x640 1 person, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.8790190975662007 deg/s
#
# 0: 384x640 1 person, 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -15.835722096178896 deg/s
#
# 0: 384x640 1 person, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.600940178160814 deg/s
#
# 0: 384x640 1 person, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 20.657035654741772 deg/s
#
# 0: 384x640 1 person, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.773480256565175 deg/s
#
# 0: 384x640 1 person, 40.3ms
# Speed: 1.0ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -6.930416245419595 deg/s
#
# 0: 384x640 1 person, 39.2ms
# Speed: 0.9ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.3211465776193378 deg/s
#
# 0: 384x640 1 person, 37.5ms
# Speed: 1.1ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 163.04860124870189 deg/s
#
# 0: 384x640 1 person, 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.1236751414070683 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.0272727908703883 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.0670590750753055 deg/s
#
# 0: 384x640 1 person, 38.1ms
# Speed: 1.0ms preprocess, 38.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.743373284224974 deg/s
#
# 0: 384x640 1 person, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.513760910732288 deg/s
#
# 0: 384x640 1 person, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 3.364362591620732 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 4.9513796474161325 deg/s
#
# 0: 384x640 1 person, 66.3ms
# Speed: 2.3ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 0.33854900658946385 deg/s
#
# 0: 384x640 1 person, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.6352449856367406 deg/s
#
# 0: 384x640 1 person, 37.3ms
# Speed: 0.8ms preprocess, 37.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.8591389563362495 deg/s
#
# 0: 384x640 1 person, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 1.0898114951395776 deg/s
#
# 0: 384x640 1 person, 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -2.5987981021528346 deg/s
#
# 0: 384x640 1 person, 64.1ms
# Speed: 1.1ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 2.254046252075651 deg/s
#
# 0: 384x640 1 person, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.1321947067432765 deg/s
#
# 0: 384x640 1 person, 39.1ms
# Speed: 0.8ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 5.412131942617168 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -1.7017666447446333 deg/s
#
# 0: 384x640 1 person, 40.8ms
# Speed: 3.7ms preprocess, 40.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.4326732101064894 deg/s
#
# 0: 384x640 1 person, 39.9ms
# Speed: 0.9ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -5.313126451129234 deg/s
#
# 0: 384x640 1 person, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -12.549187609050039 deg/s
#
# 0: 384x640 1 person, 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -3.9989348822567052 deg/s
#
# 0: 384x640 1 person, 38.8ms
# Speed: 0.9ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: 7.854361178470572 deg/s
#
# 0: 384x640 1 person, 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: -0.04716741046247423 deg/s
#
# 0: 384x640 1 person, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# Angular Velocity: nan deg/s
#
# 0: 384x640 (no detections), 38.0ms
# Speed: 0.9ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 37.9ms
# Speed: 0.9ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
# /var/folders/tq/g1l9zgqd2kn51pb90m2vx03w0000gn/T/ipykernel_54259/1546228442.py:107: RuntimeWarning: invalid value encountered in divide
#   angle_rad = math.acos(dot_product / (magnitude1 * magnitude2))
# 0: 384x640 (no detections), 41.0ms
# Speed: 0.9ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 1.8ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 0.8ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 0.9ms preprocess, 39.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 0.8ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 1.3ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 37.4ms
# Speed: 1.3ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
#
# 0: 384x640 (no detections), 38.1ms
# Speed: 0.9ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# index 0
# index 0 is out of bounds for axis 0 with size 0
